# %%
import pandas as pd
import sqlite3

# %%
cnx = sqlite3.connect('../../student-life-study-data/rawaccfeat/accfeat_u00.db')

# %%
rawacc = pd.read_sql_query("SELECT * FROM accfeat", cnx)

# %%
rawacc
# Out:
#                  time                                          feat_data
# 0        1.364096e+09  b'?\xf0j\xac\xe6\xae\xf6\xad?\xc5\xf1\xa6EC\xa...
# 1        1.364096e+09  b"?\xf0\xb7\xd0\xaf3k\xc3?\xaa\x15-z9\xf3\xbe?...
# 2        1.364096e+09  b'?\xf0\xb9\x95\xee\xbe\xc2\xf6?\xa7\x81\r\xd2...
# 3        1.364096e+09  b'?\xf0\xb9\x18\xb5\xf9)\x02?\x98\x80k\x82\xd0...
# 4        1.364096e+09  b'?\xf0\xb7\x9e)\x1b\x9b\x14?\x9a\xb2\xac\xe1\...
# 5        1.364096e+09  b'?\xf0\xad\xbc29\xb9A?\xa4x\x0c\xf3$\x14\xd7?...
# 6        1.364096e+09  b'?\xf0\xb3"d\xe7\x06\xff?\xa0\x9fX\x92\xdbh\x...
# 7        1.364096e+09  b'?\xf0\xaa\xb0W\xb3\xcc\xec?\xa3K"Unw\xfb?P\x...
# 8        1.364096e+09  b'?\xf0\xafu\xd2@\x96\xa5?\xa6?\xf9\xbd\xee\n*...
# 9        1.364096e+09  b'?\xf0\xb7\xd7\x15\xe9\xcc\xd1?\xa7}\x8d;\xc3...
# 10       1.364096e+09  b'?\xf0\x9f\xa9y\xa7-Y?\xaa\xcek+\x12\x06\x03?...
# 11       1.364096e+09  b'?\xf0\xac\x19\x99\x04;\xeb?\xaa]\xd4\x83\xa4...
# ...
